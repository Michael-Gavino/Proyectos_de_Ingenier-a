# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-Gavino/Proyectos_de_Ingenier-a/blob/main/Proyectos_de_Ingenier%C3%ADa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA 2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import requests
from io import StringIO

# %%
# Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Proyectos de ingeniería /Base de datos ad_viz_plotval_data_2022.csv")
df.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration Units  \
# 0  01/01/2022    AQS  320030561    1                                0.2   ppm
# 1  01/02/2022    AQS  320030561    1                                0.7   ppm
# 2  01/03/2022    AQS  320030561    1                                1.3   ppm
# 3  01/04/2022    AQS  320030561    1                                1.1   ppm
# 4  01/05/2022    AQS  320030561    1                                1.4   ppm
#
#    Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  ...  \
# 0                2   Sunrise Acres               19              79.0  ...
# 1                8   Sunrise Acres               24             100.0  ...
# 2               15   Sunrise Acres               24             100.0  ...
# 3               13   Sunrise Acres               24             100.0  ...
# 4               16   Sunrise Acres               24             100.0  ...
#
#    AQS Parameter Description Method Code  CBSA Code  \
# 0            Carbon monoxide          93      29820
# 1            Carbon monoxide          93      29820
# 2            Carbon monoxide          93      29820
# 3            Carbon monoxide          93      29820
# 4            Carbon monoxide          93      29820
#
#                           CBSA Name State FIPS Code   State County FIPS Code  \
# 0  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 1  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 2  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 3  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 4  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
#
#    County Site Latitude  Site Longitude
# 0   Clark     36.163962      -115.11393
# 1   Clark     36.163962      -115.11393
# 2   Clark     36.163962      -115.11393
# 3   Clark     36.163962      -115.11393
# 4   Clark     36.163962      -115.11393
#
# [5 rows x 21 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               365 non-null    object
#  1   Source                             365 non-null    object
#  2   Site ID                            365 non-null    int64
#  3   POC                                365 non-null    int64
#  4   Daily Max 8-hour CO Concentration  365 non-null    float64
#  5   Units                              365 non-null    object
#  6   Daily AQI Value                    365 non-null    int64
#  7   Local Site Name                    365 non-null    object
#  8   Daily Obs Count                    365 non-null    int64
#  9   Percent Complete                   365 non-null    float64
#  10  AQS Parameter Code                 365 non-null    int64
#  11  AQS Parameter Description          365 non-null    object
#  12  Method Code                        365 non-null    int64
#  13  CBSA Code                          365 non-null    int64
#  14  CBSA Name                          365 non-null    object
#  15  State FIPS Code                    365 non-null    int64
#  16  State                              365 non-null    object
#  17  County FIPS Code                   365 non-null    int64
#  18  County                             365 non-null    object
#  19  Site Latitude                      365 non-null    float64
#  20  Site Longitude                     365 non-null    float64
# dtypes: float64(4), int64(9), object(8)
# memory usage: 60.0+ KB

# %%
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#            Site ID    POC  Daily Max 8-hour CO Concentration  Daily AQI Value  \
# count        365.0  365.0                         365.000000       365.000000
# mean   320030561.0    1.0                           0.634521         7.164384
# std            0.0    0.0                           0.498418         5.742682
# min    320030561.0    1.0                           0.000000         0.000000
# 10%    320030561.0    1.0                           0.100000         1.000000
# 25%    320030561.0    1.0                           0.200000         2.000000
# 50%    320030561.0    1.0                           0.500000         6.000000
# 75%    320030561.0    1.0                           0.900000        10.000000
# 90%    320030561.0    1.0                           1.400000        16.000000
# max    320030561.0    1.0                           2.300000        26.000000
#
#        Daily Obs Count  Percent Complete  AQS Parameter Code  Method Code  \
# count       365.000000        365.000000               365.0        365.0
# mean         23.838356         99.326027             42101.0         93.0
# std           1.065780          4.439521                 0.0          0.0
# min          13.000000         54.000000             42101.0         93.0
# 10%          24.000000        100.000000             42101.0         93.0
# 25%          24.000000        100.000000             42101.0         93.0
# 50%          24.000000        100.000000             42101.0         93.0
# 75%          24.000000        100.000000             42101.0         93.0
# 90%          24.000000        100.000000             42101.0         93.0
# max          24.000000        100.000000             42101.0         93.0
#
#        CBSA Code  State FIPS Code  County FIPS Code  Site Latitude  \
# count      365.0            365.0             365.0   3.650000e+02
# mean     29820.0             32.0               3.0   3.616396e+01
# std          0.0              0.0               0.0   7.115181e-15
# min      29820.0             32.0               3.0   3.616396e+01
# 10%      29820.0             32.0               3.0   3.616396e+01
# 25%      29820.0             32.0               3.0   3.616396e+01
# 50%      29820.0             32.0               3.0   3.616396e+01
# 75%      29820.0             32.0               3.0   3.616396e+01
# 90%      29820.0             32.0               3.0   3.616396e+01
# max      29820.0             32.0               3.0   3.616396e+01
#
#        Site Longitude
# count    3.650000e+02
# mean    -1.151139e+02
# std      1.423036e-14
# min     -1.151139e+02
# 10%     -1.151139e+02
# 25%     -1.151139e+02
# 50%     -1.151139e+02
# 75%     -1.151139e+02
# 90%     -1.151139e+02
# max     -1.151139e+02

# %%
df.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Max 8-hour CO Concentration',
#        'Units', 'Daily AQI Value', 'Local Site Name', 'Daily Obs Count',
#        'Percent Complete', 'AQS Parameter Code', 'AQS Parameter Description',
#        'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code', 'State',
#        'County FIPS Code', 'County', 'Site Latitude', 'Site Longitude'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
df['Daily Max 8-hour CO Concentration'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily Max 8-hour CO Concentration'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Daily AQI Value'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily AQI Value'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
numeric_df = df.select_dtypes(include=[np.number])
numeric_df.corr()
# Out:
#                                    Site ID  POC  \
# Site ID                                NaN  NaN
# POC                                    NaN  NaN
# Daily Max 8-hour CO Concentration      NaN  NaN
# Daily AQI Value                        NaN  NaN
# Daily Obs Count                        NaN  NaN
# Percent Complete                       NaN  NaN
# AQS Parameter Code                     NaN  NaN
# Method Code                            NaN  NaN
# CBSA Code                              NaN  NaN
# State FIPS Code                        NaN  NaN
# County FIPS Code                       NaN  NaN
# Site Latitude                          NaN  NaN
# Site Longitude                         NaN  NaN
#
#                                    Daily Max 8-hour CO Concentration  \
# Site ID                                                          NaN
# POC                                                              NaN
# Daily Max 8-hour CO Concentration                           1.000000
# Daily AQI Value                                             0.998721
# Daily Obs Count                                             0.069491
# Percent Complete                                            0.069766
# AQS Parameter Code                                               NaN
# Method Code                                                      NaN
# CBSA Code                                                        NaN
# State FIPS Code                                                  NaN
# County FIPS Code                                                 NaN
# Site Latitude                                                    NaN
# Site Longitude                                                   NaN
#
#                                    Daily AQI Value  Daily Obs Count  \
# Site ID                                        NaN              NaN
# POC                                            NaN              NaN
# Daily Max 8-hour CO Concentration         0.998721         0.069491
# Daily AQI Value                           1.000000         0.068541
# Daily Obs Count                           0.068541         1.000000
# Percent Complete                          0.068797         0.999971
# AQS Parameter Code                             NaN              NaN
# Method Code                                    NaN              NaN
# CBSA Code                                      NaN              NaN
# State FIPS Code                                NaN              NaN
# County FIPS Code                               NaN              NaN
# Site Latitude                                  NaN              NaN
# Site Longitude                                 NaN              NaN
#
#                                    Percent Complete  AQS Parameter Code  \
# Site ID                                         NaN                 NaN
# POC                                             NaN                 NaN
# Daily Max 8-hour CO Concentration          0.069766                 NaN
# Daily AQI Value                            0.068797                 NaN
# Daily Obs Count                            0.999971                 NaN
# Percent Complete                           1.000000                 NaN
# AQS Parameter Code                              NaN                 NaN
# Method Code                                     NaN                 NaN
# CBSA Code                                       NaN                 NaN
# State FIPS Code                                 NaN                 NaN
# County FIPS Code                                NaN                 NaN
# Site Latitude                                   NaN                 NaN
# Site Longitude                                  NaN                 NaN
#
#                                    Method Code  CBSA Code  State FIPS Code  \
# Site ID                                    NaN        NaN              NaN
# POC                                        NaN        NaN              NaN
# Daily Max 8-hour CO Concentration          NaN        NaN              NaN
# Daily AQI Value                            NaN        NaN              NaN
# Daily Obs Count                            NaN        NaN              NaN
# Percent Complete                           NaN        NaN              NaN
# AQS Parameter Code                         NaN        NaN              NaN
# Method Code                                NaN        NaN              NaN
# CBSA Code                                  NaN        NaN              NaN
# State FIPS Code                            NaN        NaN              NaN
# County FIPS Code                           NaN        NaN              NaN
# Site Latitude                              NaN        NaN              NaN
# Site Longitude                             NaN        NaN              NaN
#
#                                    County FIPS Code  Site Latitude  \
# Site ID                                         NaN            NaN
# POC                                             NaN            NaN
# Daily Max 8-hour CO Concentration               NaN            NaN
# Daily AQI Value                                 NaN            NaN
# Daily Obs Count                                 NaN            NaN
# Percent Complete                                NaN            NaN
# AQS Parameter Code                              NaN            NaN
# Method Code                                     NaN            NaN
# CBSA Code                                       NaN            NaN
# State FIPS Code                                 NaN            NaN
# County FIPS Code                                NaN            NaN
# Site Latitude                                   NaN            NaN
# Site Longitude                                  NaN            NaN
#
#                                    Site Longitude
# Site ID                                       NaN
# POC                                           NaN
# Daily Max 8-hour CO Concentration             NaN
# Daily AQI Value                               NaN
# Daily Obs Count                               NaN
# Percent Complete                              NaN
# AQS Parameter Code                            NaN
# Method Code                                   NaN
# CBSA Code                                     NaN
# State FIPS Code                               NaN
# County FIPS Code                              NaN
# Site Latitude                                 NaN
# Site Longitude                                NaN

# %%
plt.figure(figsize=(10,7))
sns.heatmap(numeric_df.corr(),annot=True,linewidths=2)
# Out:
# <Axes: >

# %%
l_column = list(df.columns) # Haciendo una lista de las columnas
len_feature = len(l_column) # Longitud de la lista de vectores de columna
l_column
# Out:
# ['Date',
#  'Source',
#  'Site ID',
#  'POC',
#  'Daily Max 8-hour CO Concentration',
#  'Units',
#  'Daily AQI Value',
#  'Local Site Name',
#  'Daily Obs Count',
#  'Percent Complete',
#  'AQS Parameter Code',
#  'AQS Parameter Description',
#  'Method Code',
#  'CBSA Code',
#  'CBSA Name',
#  'State FIPS Code',
#  'State',
#  'County FIPS Code',
#  'County',
#  'Site Latitude',
#  'Site Longitude']

# %%
X = df[l_column[4:len_feature-16]]
y = df[l_column[len_feature-15]]

# %%
print("Tamaño de Características:",X.shape)
print("Tamaño de Variable Objetivo:",y.shape)
# Out:
# Tamaño de Características: (365, 19)
# Tamaño de Variable Objetivo: (365,)

# %%
X.head()
# Out:
#    Daily Max 8-hour CO Concentration
# 0                                0.2
# 1                                0.7
# 2                                1.3
# 3                                1.1
# 4                                1.4

# %%
y.head()
# Out:
# 0     2
# 1     8
# 2    15
# 3    13
# 4    16
# Name: Daily AQI Value, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
print("Tamaño del conjunto de características del entrenamiento:",X_train.shape)
print("Tamaño del conjunto de características de prueba:",X_test.shape)
print("Tamaño de la variable objetivo del entrenamiento:",y_train.shape)
print("Tamaño de la variable objetivo de prueba:",y_test.shape)
# Out:
# Tamaño del conjunto de características del entrenamiento: (255, 1)
# Tamaño del conjunto de características de prueba: (110, 1)
# Tamaño de la variable objetivo del entrenamiento: (255,)
# Tamaño de la variable objetivo de prueba: (110,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
lm = LinearRegression() # Creando un objeto de Regresión Lineal 'lm'

# %%
lm.fit(X_train,y_train) # Ajuste el modelo lineal en el objeto 'lm' en sí, es decir, no es necesario establecer esto en otra variable
# Out:
# LinearRegression()

# %%
print("El término de intersección del modelo lineal:", lm.intercept_)
# Out:
# El término de intersección del modelo lineal: -0.18519613949817781

# %%
print("Los coeficientes del modelo lineal:", lm.coef_)
# Out:
# Los coeficientes del modelo lineal: [11.58338638]

# %%
#idict = {'Coefficients':lm.intercept_}
#idf = pd.DataFrame(data=idict,index=['Intercept'])
cdf = pd.DataFrame(data=lm.coef_, index=X_train.columns, columns=["Coefficients"])
#cdf=pd.concat([idf,cdf], axis=0)
cdf
# Out:
#                                    Coefficients
# Daily Max 8-hour CO Concentration     11.583386

# %%
n=X_train.shape[0]
k=X_train.shape[1]
dfN = n-k
train_pred=lm.predict(X_train)
train_error = np.square(train_pred - y_train)
sum_error=np.sum(train_error)
se=[0]
for i in range(k):
    r = (sum_error/dfN)
    r = r/np.sum(np.square(X_train[list(X_train.columns)[i]]-X_train[list(X_train.columns)[i]].mean()))
    se[i]=np.sqrt(r)
cdf['Standard Error']=se
cdf['t-statistic']=cdf['Coefficients']/cdf['Standard Error']
cdf
# Out:
#                                    Coefficients  Standard Error  t-statistic
# Daily Max 8-hour CO Concentration     11.583386        0.036726   315.395934

# %%
print("Por lo tanto, las características organizadas en orden de importancia para predecir el precio de la vivienda\n",'-'*90,sep='')
l=list(cdf.sort_values('t-statistic',ascending=False).index)
print(' > \n'.join(l))
# Out:
# Por lo tanto, las características organizadas en orden de importancia para predecir el precio de la vivienda
# ------------------------------------------------------------------------------------------
# Daily Max 8-hour CO Concentration

# %%
l=list(cdf.index)
from matplotlib import gridspec
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(2,3)
#f, ax = plt.subplots(nrows=1,ncols=len(l), sharey=True)
ax = plt.subplot(gs[0])
ax.scatter(df[l[0]],df['Daily AQI Value'])
ax.set_title(l[0]+" vs. Daily AQI Value", fontdict={'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Daily Max 8-hour CO Concentration vs. Daily AQI Value')

# %%
print("Valor del R cuadrado de este ajuste:",round(metrics.r2_score(y_train,train_pred),3))
# Out:
# Valor del R cuadrado de este ajuste: 0.997

# %% [markdown]
# # Previsto - 2022

# %%
predictions = lm.predict(X_test)
print ("Tipo del objeto predicho :", type(predictions))
print ("Tamaño del objeto predicho:", predictions.shape)
# Out:
# Tipo del objeto predicho : <class 'numpy.ndarray'>
# Tamaño del objeto predicho: (110,)

# %%
plt.figure(figsize=(10,7))
plt.title("Daily AQI Value real vs. el predicho",fontsize=25)
plt.xlabel("Conjunto real de Daily AQI Value",fontsize=18)
plt.ylabel("Daily AQI Value predicho", fontsize=18)
plt.scatter(x=y_test,y=predictions)

# %%
plt.figure(figsize=(10,7))
plt.title("Histograma de residuos para verificar la normalidad ",fontsize=25)
plt.xlabel("Residuos",fontsize=18)
plt.ylabel("Densidad del kernel", fontsize=18)
sns.distplot([y_test-predictions])
# Out:
# <ipython-input-118-796888ce873c>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([y_test-predictions])
# <Axes: title={'center': 'Histograma de residuos para verificar la normalidad '}, xlabel='Residuos', ylabel='Densidad del kernel'>

# %%
plt.figure(figsize=(10,7))
plt.title("Valores residuales vs. predichos\n",fontsize=25)
plt.xlabel("Precios predichos de casas",fontsize=18)
plt.ylabel("Residuos", fontsize=18)
plt.scatter(x=predictions,y=y_test-predictions)

# %%
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# Mean absolute error (MAE): 0.26770217966368365
# Mean square error (MSE): 0.10449189160223706
# Root mean square error (RMSE): 0.3232520558360566

# %%
print("Valor R-squared de las predicciones:",round(metrics.r2_score(y_test,predictions),3))
# Out:
# Valor R-squared de las predicciones: 0.997

# %% [markdown]
# # DATA 2023

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import requests
from io import StringIO

# %%
df = pd.read_csv("/content/drive/MyDrive/Proyectos de ingeniería /Base de datos ad_viz_plotval_data_2023.csv")
df.head()
try:
    response = requests.get(df)
    response.raise_for_status()  # Verifica si hubo errores en la solicitud
    csv_data = StringIO(response.text)
    df = pd.read_csv(csv_data)
    print(df)
except Exception as e:
    print(f'Ocurrió un error: {e}')
# Out:
# Ocurrió un error: Invalid URL 'Date Source    Site ID  POC  Daily Max 8-hour CO Concentration  \\\n0    01/01/2023    AQS  320030561    1                                0.2   \n1    01/02/2023    AQS  320030561    1                                0.3   \n2    01/03/2023    AQS  320030561    1                                0.4   \n3    01/04/2023    AQS  320030561    1                                1.1   \n4    01/05/2023    AQS  320030561    1                                0.7   \n..          ...    ...        ...  ...                                ...   \n353  12/27/2023    AQS  320030561    1                                1.6   \n354  12/28/2023    AQS  320030561    1                                1.5   \n355  12/29/2023    AQS  320030561    1                                1.7   \n356  12/30/2023    AQS  320030561    1                                1.8   \n357  12/31/2023    AQS  320030561    1                                0.7   \n\n    Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \\\n0     ppm                2   Sunrise Acres               19              79.0   \n1     ppm                3   Sunrise Acres               24             100.0   \n2     ppm                5   Sunrise Acres               24             100.0   \n3     ppm               13   Sunrise Acres               24             100.0   \n4     ppm                8   Sunrise Acres               24             100.0   \n..    ...              ...             ...              ...               ...   \n353   ppm               18   Sunrise Acres               24             100.0   \n354   ppm               17   Sunrise Acres               24             100.0   \n355   ppm               19   Sunrise Acres               24             100.0   \n356   ppm               20   Sunrise Acres               24             100.0   \n357   ppm                8   Sunrise Acres               24             100.0   \n\n     ...  AQS Parameter Description Method Code  CBSA Code  \\\n0    ...            Carbon monoxide          93      29820   \n1    ...            Carbon monoxide          93      29820   \n2    ...            Carbon monoxide          93      29820   \n3    ...            Carbon monoxide          93      29820   \n4    ...            Carbon monoxide          93      29820   \n..   ...                        ...         ...        ...   \n353  ...            Carbon monoxide          93      29820   \n354  ...            Carbon monoxide          93      29820   \n355  ...            Carbon monoxide          93      29820   \n356  ...            Carbon monoxide          93      29820   \n357  ...            Carbon monoxide          93      29820   \n\n                            CBSA Name State FIPS Code   State  \\\n0    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n1    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n2    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n3    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n4    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n..                                ...             ...     ...   \n353  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n354  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n355  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n356  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n357  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n\n    County FIPS Code  County Site Latitude  Site Longitude  \n0                  3   Clark     36.163962      -115.11393  \n1                  3   Clark     36.163962      -115.11393  \n2                  3   Clark     36.163962      -115.11393  \n3                  3   Clark     36.163962      -115.11393  \n4                  3   Clark     36.163962      -115.11393  \n..               ...     ...           ...             ...  \n353                3   Clark     36.163962      -115.11393  \n354  ...
# 0    01/01/2023    AQS  320030561    1                                0.2
# 1    01/02/2023    AQS  320030561    1                                0.3
# 2    01/03/2023    AQS  320030561    1                                0.4
# 3    01/04/2023    AQS  320030561    1                                1.1
# 4    01/05/2023    AQS  320030561    1                                0.7
# ..          ...    ...        ...  ...                                ...
# 353  12/27/2023    AQS  320030561    1                                1.6
# 354  12/28/2023    AQS  320030561    1                                1.5
# 355  12/29/2023    AQS  320030561    1                                1.7
# 356  12/30/2023    AQS  320030561    1                                1.8
# 357  12/31/2023    AQS  320030561    1                                0.7
#
#     Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \
# 0     ppm                2   Sunrise Acres               19              79.0
# 1     ppm                3   Sunrise Acres               24             100.0
# 2     ppm                5   Sunrise Acres               24             100.0
# 3     ppm               13   Sunrise Acres               24             100.0
# 4     ppm                8   Sunrise Acres               24             100.0
# ..    ...              ...             ...              ...               ...
# 353   ppm               18   Sunrise Acres               24             100.0
# 354   ppm               17   Sunrise Acres               24             100.0
# 355   ppm               19   Sunrise Acres               24             100.0
# 356   ppm               20   Sunrise Acres               24             100.0
# 357   ppm                8   Sunrise Acres               24             100.0
#
#      ...  AQS Parameter Description Method Code  CBSA Code  \
# 0    ...            Carbon monoxide          93      29820
# 1    ...            Carbon monoxide          93      29820
# 2    ...            Carbon monoxide          93      29820
# 3    ...            Carbon monoxide          93      29820
# 4    ...            Carbon monoxide          93      29820
# ..   ...                        ...         ...        ...
# 353  ...            Carbon monoxide          93      29820
# 354  ...            Carbon monoxide          93      29820
# 355  ...            Carbon monoxide          93      29820
# 356  ...            Carbon monoxide          93      29820
# 357  ...            Carbon monoxide          93      29820
#
#                             CBSA Name State FIPS Code   State  \
# 0    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 1    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 2    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 3    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 4    Las Vegas-Henderson-Paradise, NV              32  Nevada
# ..                                ...             ...     ...
# 353  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 354  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 355  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 356  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 357  Las Vegas-Henderson-Paradise, NV              32  Nevada
#
#     County FIPS Code  County Site Latitude  Site Longitude
# 0                  3   Clark     36.163962      -115.11393
# 1                  3   Clark     36.163962      -115.11393
# 2                  3   Clark     36.163962      -115.11393
# 3                  3   Clark     36.163962      -115.11393
# 4                  3   Clark     36.163962      -115.11393
# ..               ...     ...           ...             ...
# 353                3   Clark     36.163962      -115.11393
# 354                3   Clark     36.163962      -115.11393
# 355                3   Clark     36.163962      -115.11393
# 356                3   Clark     36.163962      -115.11393
# 357                3   Clark     36.163962      -115.11393
#
# [358 rows x 21 columns]?

# %%
df.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration Units  \
# 0  01/01/2023    AQS  320030561    1                                0.2   ppm
# 1  01/02/2023    AQS  320030561    1                                0.3   ppm
# 2  01/03/2023    AQS  320030561    1                                0.4   ppm
# 3  01/04/2023    AQS  320030561    1                                1.1   ppm
# 4  01/05/2023    AQS  320030561    1                                0.7   ppm
#
#    Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  ...  \
# 0                2   Sunrise Acres               19              79.0  ...
# 1                3   Sunrise Acres               24             100.0  ...
# 2                5   Sunrise Acres               24             100.0  ...
# 3               13   Sunrise Acres               24             100.0  ...
# 4                8   Sunrise Acres               24             100.0  ...
#
#    AQS Parameter Description Method Code  CBSA Code  \
# 0            Carbon monoxide          93      29820
# 1            Carbon monoxide          93      29820
# 2            Carbon monoxide          93      29820
# 3            Carbon monoxide          93      29820
# 4            Carbon monoxide          93      29820
#
#                           CBSA Name State FIPS Code   State County FIPS Code  \
# 0  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 1  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 2  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 3  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 4  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
#
#    County Site Latitude  Site Longitude
# 0   Clark     36.163962      -115.11393
# 1   Clark     36.163962      -115.11393
# 2   Clark     36.163962      -115.11393
# 3   Clark     36.163962      -115.11393
# 4   Clark     36.163962      -115.11393
#
# [5 rows x 21 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               358 non-null    object
#  1   Source                             358 non-null    object
#  2   Site ID                            358 non-null    int64
#  3   POC                                358 non-null    int64
#  4   Daily Max 8-hour CO Concentration  358 non-null    float64
#  5   Units                              358 non-null    object
#  6   Daily AQI Value                    358 non-null    int64
#  7   Local Site Name                    358 non-null    object
#  8   Daily Obs Count                    358 non-null    int64
#  9   Percent Complete                   358 non-null    float64
#  10  AQS Parameter Code                 358 non-null    int64
#  11  AQS Parameter Description          358 non-null    object
#  12  Method Code                        358 non-null    int64
#  13  CBSA Code                          358 non-null    int64
#  14  CBSA Name                          358 non-null    object
#  15  State FIPS Code                    358 non-null    int64
#  16  State                              358 non-null    object
#  17  County FIPS Code                   358 non-null    int64
#  18  County                             358 non-null    object
#  19  Site Latitude                      358 non-null    float64
#  20  Site Longitude                     358 non-null    float64
# dtypes: float64(4), int64(9), object(8)
# memory usage: 58.9+ KB

# %%
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#            Site ID    POC  Daily Max 8-hour CO Concentration  Daily AQI Value  \
# count        358.0  358.0                         358.000000       358.000000
# mean   320030561.0    1.0                           0.585754         6.614525
# std            0.0    0.0                           0.497775         5.745490
# min    320030561.0    1.0                           0.000000         0.000000
# 10%    320030561.0    1.0                           0.100000         1.000000
# 25%    320030561.0    1.0                           0.200000         2.000000
# 50%    320030561.0    1.0                           0.400000         5.000000
# 75%    320030561.0    1.0                           0.900000        10.000000
# 90%    320030561.0    1.0                           1.300000        15.000000
# max    320030561.0    1.0                           2.200000        25.000000
#
#        Daily Obs Count  Percent Complete  AQS Parameter Code  Method Code  \
# count       358.000000        358.000000               358.0        358.0
# mean         23.337989         97.245810             42101.0         93.0
# std           2.573352         10.716929                 0.0          0.0
# min           5.000000         21.000000             42101.0         93.0
# 10%          24.000000        100.000000             42101.0         93.0
# 25%          24.000000        100.000000             42101.0         93.0
# 50%          24.000000        100.000000             42101.0         93.0
# 75%          24.000000        100.000000             42101.0         93.0
# 90%          24.000000        100.000000             42101.0         93.0
# max          24.000000        100.000000             42101.0         93.0
#
#        CBSA Code  State FIPS Code  County FIPS Code  Site Latitude  \
# count      358.0            358.0             358.0   3.580000e+02
# mean     29820.0             32.0               3.0   3.616396e+01
# std          0.0              0.0               0.0   7.115372e-15
# min      29820.0             32.0               3.0   3.616396e+01
# 10%      29820.0             32.0               3.0   3.616396e+01
# 25%      29820.0             32.0               3.0   3.616396e+01
# 50%      29820.0             32.0               3.0   3.616396e+01
# 75%      29820.0             32.0               3.0   3.616396e+01
# 90%      29820.0             32.0               3.0   3.616396e+01
# max      29820.0             32.0               3.0   3.616396e+01
#
#        Site Longitude
# count       358.00000
# mean       -115.11393
# std           0.00000
# min        -115.11393
# 10%        -115.11393
# 25%        -115.11393
# 50%        -115.11393
# 75%        -115.11393
# 90%        -115.11393
# max        -115.11393

# %%
df.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Max 8-hour CO Concentration',
#        'Units', 'Daily AQI Value', 'Local Site Name', 'Daily Obs Count',
#        'Percent Complete', 'AQS Parameter Code', 'AQS Parameter Description',
#        'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code', 'State',
#        'County FIPS Code', 'County', 'Site Latitude', 'Site Longitude'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
df['Daily Max 8-hour CO Concentration'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily Max 8-hour CO Concentration'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Daily AQI Value'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily AQI Value'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
numeric_df = df.select_dtypes(include=[np.number])
numeric_df.corr()
# Out:
#                                    Site ID  POC  \
# Site ID                                NaN  NaN
# POC                                    NaN  NaN
# Daily Max 8-hour CO Concentration      NaN  NaN
# Daily AQI Value                        NaN  NaN
# Daily Obs Count                        NaN  NaN
# Percent Complete                       NaN  NaN
# AQS Parameter Code                     NaN  NaN
# Method Code                            NaN  NaN
# CBSA Code                              NaN  NaN
# State FIPS Code                        NaN  NaN
# County FIPS Code                       NaN  NaN
# Site Latitude                          NaN  NaN
# Site Longitude                         NaN  NaN
#
#                                    Daily Max 8-hour CO Concentration  \
# Site ID                                                          NaN
# POC                                                              NaN
# Daily Max 8-hour CO Concentration                           1.000000
# Daily AQI Value                                             0.998755
# Daily Obs Count                                            -0.017442
# Percent Complete                                           -0.018140
# AQS Parameter Code                                               NaN
# Method Code                                                      NaN
# CBSA Code                                                        NaN
# State FIPS Code                                                  NaN
# County FIPS Code                                                 NaN
# Site Latitude                                                    NaN
# Site Longitude                                                   NaN
#
#                                    Daily AQI Value  Daily Obs Count  \
# Site ID                                        NaN              NaN
# POC                                            NaN              NaN
# Daily Max 8-hour CO Concentration         0.998755        -0.017442
# Daily AQI Value                           1.000000        -0.017498
# Daily Obs Count                          -0.017498         1.000000
# Percent Complete                         -0.018200         0.999975
# AQS Parameter Code                             NaN              NaN
# Method Code                                    NaN              NaN
# CBSA Code                                      NaN              NaN
# State FIPS Code                                NaN              NaN
# County FIPS Code                               NaN              NaN
# Site Latitude                                  NaN              NaN
# Site Longitude                                 NaN              NaN
#
#                                    Percent Complete  AQS Parameter Code  \
# Site ID                                         NaN                 NaN
# POC                                             NaN                 NaN
# Daily Max 8-hour CO Concentration         -0.018140                 NaN
# Daily AQI Value                           -0.018200                 NaN
# Daily Obs Count                            0.999975                 NaN
# Percent Complete                           1.000000                 NaN
# AQS Parameter Code                              NaN                 NaN
# Method Code                                     NaN                 NaN
# CBSA Code                                       NaN                 NaN
# State FIPS Code                                 NaN                 NaN
# County FIPS Code                                NaN                 NaN
# Site Latitude                                   NaN                 NaN
# Site Longitude                                  NaN                 NaN
#
#                                    Method Code  CBSA Code  State FIPS Code  \
# Site ID                                    NaN        NaN              NaN
# POC                                        NaN        NaN              NaN
# Daily Max 8-hour CO Concentration          NaN        NaN              NaN
# Daily AQI Value                            NaN        NaN              NaN
# Daily Obs Count                            NaN        NaN              NaN
# Percent Complete                           NaN        NaN              NaN
# AQS Parameter Code                         NaN        NaN              NaN
# Method Code                                NaN        NaN              NaN
# CBSA Code                                  NaN        NaN              NaN
# State FIPS Code                            NaN        NaN              NaN
# County FIPS Code                           NaN        NaN              NaN
# Site Latitude                              NaN        NaN              NaN
# Site Longitude                             NaN        NaN              NaN
#
#                                    County FIPS Code  Site Latitude  \
# Site ID                                         NaN            NaN
# POC                                             NaN            NaN
# Daily Max 8-hour CO Concentration               NaN            NaN
# Daily AQI Value                                 NaN            NaN
# Daily Obs Count                                 NaN            NaN
# Percent Complete                                NaN            NaN
# AQS Parameter Code                              NaN            NaN
# Method Code                                     NaN            NaN
# CBSA Code                                       NaN            NaN
# State FIPS Code                                 NaN            NaN
# County FIPS Code                                NaN            NaN
# Site Latitude                                   NaN            NaN
# Site Longitude                                  NaN            NaN
#
#                                    Site Longitude
# Site ID                                       NaN
# POC                                           NaN
# Daily Max 8-hour CO Concentration             NaN
# Daily AQI Value                               NaN
# Daily Obs Count                               NaN
# Percent Complete                              NaN
# AQS Parameter Code                            NaN
# Method Code                                   NaN
# CBSA Code                                     NaN
# State FIPS Code                               NaN
# County FIPS Code                              NaN
# Site Latitude                                 NaN
# Site Longitude                                NaN

# %%
plt.figure(figsize=(10,7))
sns.heatmap(numeric_df.corr(),annot=True,linewidths=2)
# Out:
# <Axes: >

# %%
l_column = list(df.columns) # Haciendo una lista de las columnas
len_feature = len(l_column) # Longitud de la lista de vectores de columna
l_column
# Out:
# ['Date',
#  'Source',
#  'Site ID',
#  'POC',
#  'Daily Max 8-hour CO Concentration',
#  'Units',
#  'Daily AQI Value',
#  'Local Site Name',
#  'Daily Obs Count',
#  'Percent Complete',
#  'AQS Parameter Code',
#  'AQS Parameter Description',
#  'Method Code',
#  'CBSA Code',
#  'CBSA Name',
#  'State FIPS Code',
#  'State',
#  'County FIPS Code',
#  'County',
#  'Site Latitude',
#  'Site Longitude']

# %%
X = df[l_column[4:len_feature-16]]
y = df[l_column[len_feature-15]]

# %%
print("Tamaño de Características:",X.shape)
print("Tamaño de Variable Objetivo:",y.shape)
# Out:
# Tamaño de Características: (358, 1)
# Tamaño de Variable Objetivo: (358,)

# %%
X.head()
# Out:
#    Daily Max 8-hour CO Concentration
# 0                                0.2
# 1                                0.3
# 2                                0.4
# 3                                1.1
# 4                                0.7

# %%
y.head()
# Out:
# 0     2
# 1     3
# 2     5
# 3    13
# 4     8
# Name: Daily AQI Value, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
print("Tamaño del conjunto de características del entrenamiento:",X_train.shape)
print("Tamaño del conjunto de características de prueba:",X_test.shape)
print("Tamaño de la variable objetivo del entrenamiento:",y_train.shape)
print("Tamaño de la variable objetivo de prueba:",y_test.shape)
# Out:
# Tamaño del conjunto de características del entrenamiento: (250, 1)
# Tamaño del conjunto de características de prueba: (108, 1)
# Tamaño de la variable objetivo del entrenamiento: (250,)
# Tamaño de la variable objetivo de prueba: (108,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
lm = LinearRegression() # Creando un objeto de Regresión Lineal 'lm'

# %%
lm.fit(X_train,y_train) # Ajuste el modelo lineal en el objeto 'lm' en sí, es decir, no es necesario establecer esto en otra variable
# Out:
# LinearRegression()

# %%
print("El término de intersección del modelo lineal:", lm.intercept_)
# Out:
# El término de intersección del modelo lineal: -0.1338815452260924

# %%
print("Los coeficientes del modelo lineal:", lm.coef_)
# Out:
# Los coeficientes del modelo lineal: [11.55526957]

# %%
#idict = {'Coefficients':lm.intercept_}
#idf = pd.DataFrame(data=idict,index=['Intercept'])
cdf = pd.DataFrame(data=lm.coef_, index=X_train.columns, columns=["Coefficients"])
#cdf=pd.concat([idf,cdf], axis=0)
cdf
# Out:
#                                    Coefficients
# Daily Max 8-hour CO Concentration      11.55527

# %%
n=X_train.shape[0]
k=X_train.shape[1]
dfN = n-k
train_pred=lm.predict(X_train)
train_error = np.square(train_pred - y_train)
sum_error=np.sum(train_error)
se=[0]
for i in range(k):
    r = (sum_error/dfN)
    r = r/np.sum(np.square(X_train[list(X_train.columns)[i]]-X_train[list(X_train.columns)[i]].mean()))
    se[i]=np.sqrt(r)
cdf['Standard Error']=se
cdf['t-statistic']=cdf['Coefficients']/cdf['Standard Error']
cdf
# Out:
#                                    Coefficients  Standard Error  t-statistic
# Daily Max 8-hour CO Concentration      11.55527        0.038158   302.825907

# %%
print("Por lo tanto, las características organizadas en orden de importancia para predecir el precio de la vivienda\n",'-'*90,sep='')
l=list(cdf.sort_values('t-statistic',ascending=False).index)
print(' > \n'.join(l))
# Out:
# Por lo tanto, las características organizadas en orden de importancia para predecir el precio de la vivienda
# ------------------------------------------------------------------------------------------
# Daily Max 8-hour CO Concentration

# %%
l=list(cdf.index)
from matplotlib import gridspec
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(2,3)
#f, ax = plt.subplots(nrows=1,ncols=len(l), sharey=True)
ax = plt.subplot(gs[0])
ax.scatter(df[l[0]],df['Daily AQI Value'])
ax.set_title(l[0]+" vs. Daily AQI Value", fontdict={'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Daily Max 8-hour CO Concentration vs. Daily AQI Value')

# %%
print("Valor del R cuadrado de este ajuste:",round(metrics.r2_score(y_train,train_pred),3))
# Out:
# Valor del R cuadrado de este ajuste: 0.997

# %% [markdown]
# #DATA 2022 Y 2023

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import requests
from io import StringIO

# %%
df = pd.read_csv("/content/drive/MyDrive/Proyectos de ingeniería /Base de datosad_viz_plotval_data_2022&2023.csv")
df.head()
try:
    response = requests.get(df)
    response.raise_for_status()  # Verifica si hubo errores en la solicitud
    csv_data = StringIO(response.text)
    df = pd.read_csv(csv_data)
    print(df)
except Exception as e:
    print(f'Ocurrió un error: {e}')
# Out:
# Ocurrió un error: Invalid URL 'Date Source    Site ID  POC  Daily Max 8-hour CO Concentration  \\\n0    01/01/2022    AQS  320030561    1                                0.2   \n1    01/02/2022    AQS  320030561    1                                0.7   \n2    01/03/2022    AQS  320030561    1                                1.3   \n3    01/04/2022    AQS  320030561    1                                1.1   \n4    01/05/2022    AQS  320030561    1                                1.4   \n..          ...    ...        ...  ...                                ...   \n718  12/27/2023    AQS  320030561    1                                1.6   \n719  12/28/2023    AQS  320030561    1                                1.5   \n720  12/29/2023    AQS  320030561    1                                1.7   \n721  12/30/2023    AQS  320030561    1                                1.8   \n722  12/31/2023    AQS  320030561    1                                0.7   \n\n    Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \\\n0     ppm                2   Sunrise Acres               19              79.0   \n1     ppm                8   Sunrise Acres               24             100.0   \n2     ppm               15   Sunrise Acres               24             100.0   \n3     ppm               13   Sunrise Acres               24             100.0   \n4     ppm               16   Sunrise Acres               24             100.0   \n..    ...              ...             ...              ...               ...   \n718   ppm               18   Sunrise Acres               24             100.0   \n719   ppm               17   Sunrise Acres               24             100.0   \n720   ppm               19   Sunrise Acres               24             100.0   \n721   ppm               20   Sunrise Acres               24             100.0   \n722   ppm                8   Sunrise Acres               24             100.0   \n\n     ...  AQS Parameter Description Method Code  CBSA Code  \\\n0    ...            Carbon monoxide          93      29820   \n1    ...            Carbon monoxide          93      29820   \n2    ...            Carbon monoxide          93      29820   \n3    ...            Carbon monoxide          93      29820   \n4    ...            Carbon monoxide          93      29820   \n..   ...                        ...         ...        ...   \n718  ...            Carbon monoxide          93      29820   \n719  ...            Carbon monoxide          93      29820   \n720  ...            Carbon monoxide          93      29820   \n721  ...            Carbon monoxide          93      29820   \n722  ...            Carbon monoxide          93      29820   \n\n                            CBSA Name State FIPS Code   State  \\\n0    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n1    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n2    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n3    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n4    Las Vegas-Henderson-Paradise, NV              32  Nevada   \n..                                ...             ...     ...   \n718  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n719  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n720  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n721  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n722  Las Vegas-Henderson-Paradise, NV              32  Nevada   \n\n    County FIPS Code  County Site Latitude  Site Longitude  \n0                  3   Clark     36.163962      -115.11393  \n1                  3   Clark     36.163962      -115.11393  \n2                  3   Clark     36.163962      -115.11393  \n3                  3   Clark     36.163962      -115.11393  \n4                  3   Clark     36.163962      -115.11393  \n..               ...     ...           ...             ...  \n718                3   Clark     36.163962      -115.11393  \n719  ...
# 0    01/01/2022    AQS  320030561    1                                0.2
# 1    01/02/2022    AQS  320030561    1                                0.7
# 2    01/03/2022    AQS  320030561    1                                1.3
# 3    01/04/2022    AQS  320030561    1                                1.1
# 4    01/05/2022    AQS  320030561    1                                1.4
# ..          ...    ...        ...  ...                                ...
# 718  12/27/2023    AQS  320030561    1                                1.6
# 719  12/28/2023    AQS  320030561    1                                1.5
# 720  12/29/2023    AQS  320030561    1                                1.7
# 721  12/30/2023    AQS  320030561    1                                1.8
# 722  12/31/2023    AQS  320030561    1                                0.7
#
#     Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \
# 0     ppm                2   Sunrise Acres               19              79.0
# 1     ppm                8   Sunrise Acres               24             100.0
# 2     ppm               15   Sunrise Acres               24             100.0
# 3     ppm               13   Sunrise Acres               24             100.0
# 4     ppm               16   Sunrise Acres               24             100.0
# ..    ...              ...             ...              ...               ...
# 718   ppm               18   Sunrise Acres               24             100.0
# 719   ppm               17   Sunrise Acres               24             100.0
# 720   ppm               19   Sunrise Acres               24             100.0
# 721   ppm               20   Sunrise Acres               24             100.0
# 722   ppm                8   Sunrise Acres               24             100.0
#
#      ...  AQS Parameter Description Method Code  CBSA Code  \
# 0    ...            Carbon monoxide          93      29820
# 1    ...            Carbon monoxide          93      29820
# 2    ...            Carbon monoxide          93      29820
# 3    ...            Carbon monoxide          93      29820
# 4    ...            Carbon monoxide          93      29820
# ..   ...                        ...         ...        ...
# 718  ...            Carbon monoxide          93      29820
# 719  ...            Carbon monoxide          93      29820
# 720  ...            Carbon monoxide          93      29820
# 721  ...            Carbon monoxide          93      29820
# 722  ...            Carbon monoxide          93      29820
#
#                             CBSA Name State FIPS Code   State  \
# 0    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 1    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 2    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 3    Las Vegas-Henderson-Paradise, NV              32  Nevada
# 4    Las Vegas-Henderson-Paradise, NV              32  Nevada
# ..                                ...             ...     ...
# 718  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 719  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 720  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 721  Las Vegas-Henderson-Paradise, NV              32  Nevada
# 722  Las Vegas-Henderson-Paradise, NV              32  Nevada
#
#     County FIPS Code  County Site Latitude  Site Longitude
# 0                  3   Clark     36.163962      -115.11393
# 1                  3   Clark     36.163962      -115.11393
# 2                  3   Clark     36.163962      -115.11393
# 3                  3   Clark     36.163962      -115.11393
# 4                  3   Clark     36.163962      -115.11393
# ..               ...     ...           ...             ...
# 718                3   Clark     36.163962      -115.11393
# 719                3   Clark     36.163962      -115.11393
# 720                3   Clark     36.163962      -115.11393
# 721                3   Clark     36.163962      -115.11393
# 722                3   Clark     36.163962      -115.11393
#
# [723 rows x 21 columns]?

# %%
df.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration Units  \
# 0  01/01/2022    AQS  320030561    1                                0.2   ppm
# 1  01/02/2022    AQS  320030561    1                                0.7   ppm
# 2  01/03/2022    AQS  320030561    1                                1.3   ppm
# 3  01/04/2022    AQS  320030561    1                                1.1   ppm
# 4  01/05/2022    AQS  320030561    1                                1.4   ppm
#
#    Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  ...  \
# 0                2   Sunrise Acres               19              79.0  ...
# 1                8   Sunrise Acres               24             100.0  ...
# 2               15   Sunrise Acres               24             100.0  ...
# 3               13   Sunrise Acres               24             100.0  ...
# 4               16   Sunrise Acres               24             100.0  ...
#
#    AQS Parameter Description Method Code  CBSA Code  \
# 0            Carbon monoxide          93      29820
# 1            Carbon monoxide          93      29820
# 2            Carbon monoxide          93      29820
# 3            Carbon monoxide          93      29820
# 4            Carbon monoxide          93      29820
#
#                           CBSA Name State FIPS Code   State County FIPS Code  \
# 0  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 1  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 2  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 3  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
# 4  Las Vegas-Henderson-Paradise, NV              32  Nevada                3
#
#    County Site Latitude  Site Longitude
# 0   Clark     36.163962      -115.11393
# 1   Clark     36.163962      -115.11393
# 2   Clark     36.163962      -115.11393
# 3   Clark     36.163962      -115.11393
# 4   Clark     36.163962      -115.11393
#
# [5 rows x 21 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723 entries, 0 to 722
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               723 non-null    object
#  1   Source                             723 non-null    object
#  2   Site ID                            723 non-null    int64
#  3   POC                                723 non-null    int64
#  4   Daily Max 8-hour CO Concentration  723 non-null    float64
#  5   Units                              723 non-null    object
#  6   Daily AQI Value                    723 non-null    int64
#  7   Local Site Name                    723 non-null    object
#  8   Daily Obs Count                    723 non-null    int64
#  9   Percent Complete                   723 non-null    float64
#  10  AQS Parameter Code                 723 non-null    int64
#  11  AQS Parameter Description          723 non-null    object
#  12  Method Code                        723 non-null    int64
#  13  CBSA Code                          723 non-null    int64
#  14  CBSA Name                          723 non-null    object
#  15  State FIPS Code                    723 non-null    int64
#  16  State                              723 non-null    object
#  17  County FIPS Code                   723 non-null    int64
#  18  County                             723 non-null    object
#  19  Site Latitude                      723 non-null    float64
#  20  Site Longitude                     723 non-null    float64
# dtypes: float64(4), int64(9), object(8)
# memory usage: 118.7+ KB

# %%
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#            Site ID    POC  Daily Max 8-hour CO Concentration  Daily AQI Value  \
# count        723.0  723.0                         723.000000       723.000000
# mean   320030561.0    1.0                           0.610373         6.892116
# std            0.0    0.0                           0.498352         5.746682
# min    320030561.0    1.0                           0.000000         0.000000
# 10%    320030561.0    1.0                           0.100000         1.000000
# 25%    320030561.0    1.0                           0.200000         2.000000
# 50%    320030561.0    1.0                           0.400000         5.000000
# 75%    320030561.0    1.0                           0.900000        10.000000
# 90%    320030561.0    1.0                           1.400000        16.000000
# max    320030561.0    1.0                           2.300000        26.000000
#
#        Daily Obs Count  Percent Complete  AQS Parameter Code  Method Code  \
# count       723.000000        723.000000               723.0        723.0
# mean         23.590595         98.295989             42101.0         93.0
# std           1.977301          8.234669                 0.0          0.0
# min           5.000000         21.000000             42101.0         93.0
# 10%          24.000000        100.000000             42101.0         93.0
# 25%          24.000000        100.000000             42101.0         93.0
# 50%          24.000000        100.000000             42101.0         93.0
# 75%          24.000000        100.000000             42101.0         93.0
# 90%          24.000000        100.000000             42101.0         93.0
# max          24.000000        100.000000             42101.0         93.0
#
#        CBSA Code  State FIPS Code  County FIPS Code  Site Latitude  \
# count      723.0            723.0             723.0   7.230000e+02
# mean     29820.0             32.0               3.0   3.616396e+01
# std          0.0              0.0               0.0   7.110346e-15
# min      29820.0             32.0               3.0   3.616396e+01
# 10%      29820.0             32.0               3.0   3.616396e+01
# 25%      29820.0             32.0               3.0   3.616396e+01
# 50%      29820.0             32.0               3.0   3.616396e+01
# 75%      29820.0             32.0               3.0   3.616396e+01
# 90%      29820.0             32.0               3.0   3.616396e+01
# max      29820.0             32.0               3.0   3.616396e+01
#
#        Site Longitude
# count       723.00000
# mean       -115.11393
# std           0.00000
# min        -115.11393
# 10%        -115.11393
# 25%        -115.11393
# 50%        -115.11393
# 75%        -115.11393
# 90%        -115.11393
# max        -115.11393

# %%
df.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Max 8-hour CO Concentration',
#        'Units', 'Daily AQI Value', 'Local Site Name', 'Daily Obs Count',
#        'Percent Complete', 'AQS Parameter Code', 'AQS Parameter Description',
#        'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code', 'State',
#        'County FIPS Code', 'County', 'Site Latitude', 'Site Longitude'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
df['Daily Max 8-hour CO Concentration'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily Max 8-hour CO Concentration'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Daily AQI Value'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Daily AQI Value'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
numeric_df = df.select_dtypes(include=[np.number])
numeric_df.corr()
# Out:
#                                    Site ID  POC  \
# Site ID                                NaN  NaN
# POC                                    NaN  NaN
# Daily Max 8-hour CO Concentration      NaN  NaN
# Daily AQI Value                        NaN  NaN
# Daily Obs Count                        NaN  NaN
# Percent Complete                       NaN  NaN
# AQS Parameter Code                     NaN  NaN
# Method Code                            NaN  NaN
# CBSA Code                              NaN  NaN
# State FIPS Code                        NaN  NaN
# County FIPS Code                       NaN  NaN
# Site Latitude                          NaN  NaN
# Site Longitude                         NaN  NaN
#
#                                    Daily Max 8-hour CO Concentration  \
# Site ID                                                          NaN
# POC                                                              NaN
# Daily Max 8-hour CO Concentration                           1.000000
# Daily AQI Value                                             0.998740
# Daily Obs Count                                             0.013874
# Percent Complete                                            0.013493
# AQS Parameter Code                                               NaN
# Method Code                                                      NaN
# CBSA Code                                                        NaN
# State FIPS Code                                                  NaN
# County FIPS Code                                                 NaN
# Site Latitude                                                    NaN
# Site Longitude                                                   NaN
#
#                                    Daily AQI Value  Daily Obs Count  \
# Site ID                                        NaN              NaN
# POC                                            NaN              NaN
# Daily Max 8-hour CO Concentration         0.998740         0.013874
# Daily AQI Value                           1.000000         0.013416
# Daily Obs Count                           0.013416         1.000000
# Percent Complete                          0.013027         0.999975
# AQS Parameter Code                             NaN              NaN
# Method Code                                    NaN              NaN
# CBSA Code                                      NaN              NaN
# State FIPS Code                                NaN              NaN
# County FIPS Code                               NaN              NaN
# Site Latitude                                  NaN              NaN
# Site Longitude                                 NaN              NaN
#
#                                    Percent Complete  AQS Parameter Code  \
# Site ID                                         NaN                 NaN
# POC                                             NaN                 NaN
# Daily Max 8-hour CO Concentration          0.013493                 NaN
# Daily AQI Value                            0.013027                 NaN
# Daily Obs Count                            0.999975                 NaN
# Percent Complete                           1.000000                 NaN
# AQS Parameter Code                              NaN                 NaN
# Method Code                                     NaN                 NaN
# CBSA Code                                       NaN                 NaN
# State FIPS Code                                 NaN                 NaN
# County FIPS Code                                NaN                 NaN
# Site Latitude                                   NaN                 NaN
# Site Longitude                                  NaN                 NaN
#
#                                    Method Code  CBSA Code  State FIPS Code  \
# Site ID                                    NaN        NaN              NaN
# POC                                        NaN        NaN              NaN
# Daily Max 8-hour CO Concentration          NaN        NaN              NaN
# Daily AQI Value                            NaN        NaN              NaN
# Daily Obs Count                            NaN        NaN              NaN
# Percent Complete                           NaN        NaN              NaN
# AQS Parameter Code                         NaN        NaN              NaN
# Method Code                                NaN        NaN              NaN
# CBSA Code                                  NaN        NaN              NaN
# State FIPS Code                            NaN        NaN              NaN
# County FIPS Code                           NaN        NaN              NaN
# Site Latitude                              NaN        NaN              NaN
# Site Longitude                             NaN        NaN              NaN
#
#                                    County FIPS Code  Site Latitude  \
# Site ID                                         NaN            NaN
# POC                                             NaN            NaN
# Daily Max 8-hour CO Concentration               NaN            NaN
# Daily AQI Value                                 NaN            NaN
# Daily Obs Count                                 NaN            NaN
# Percent Complete                                NaN            NaN
# AQS Parameter Code                              NaN            NaN
# Method Code                                     NaN            NaN
# CBSA Code                                       NaN            NaN
# State FIPS Code                                 NaN            NaN
# County FIPS Code                                NaN            NaN
# Site Latitude                                   NaN            NaN
# Site Longitude                                  NaN            NaN
#
#                                    Site Longitude
# Site ID                                       NaN
# POC                                           NaN
# Daily Max 8-hour CO Concentration             NaN
# Daily AQI Value                               NaN
# Daily Obs Count                               NaN
# Percent Complete                              NaN
# AQS Parameter Code                            NaN
# Method Code                                   NaN
# CBSA Code                                     NaN
# State FIPS Code                               NaN
# County FIPS Code                              NaN
# Site Latitude                                 NaN
# Site Longitude                                NaN

# %%
plt.figure(figsize=(10,7))
sns.heatmap(numeric_df.corr(),annot=True,linewidths=2)
# Out:
# <Axes: >

# %%
l_column = list(df.columns) # Haciendo una lista de las columnas
len_feature = len(l_column) # Longitud de la lista de vectores de columna
l_column
# Out:
# ['Date',
#  'Source',
#  'Site ID',
#  'POC',
#  'Daily Max 8-hour CO Concentration',
#  'Units',
#  'Daily AQI Value',
#  'Local Site Name',
#  'Daily Obs Count',
#  'Percent Complete',
#  'AQS Parameter Code',
#  'AQS Parameter Description',
#  'Method Code',
#  'CBSA Code',
#  'CBSA Name',
#  'State FIPS Code',
#  'State',
#  'County FIPS Code',
#  'County',
#  'Site Latitude',
#  'Site Longitude']

# %%
X = df[l_column[4:len_feature-16]]
y = df[l_column[len_feature-15]]

# %%
print("Tamaño de Características:",X.shape)
print("Tamaño de Variable Objetivo:",y.shape)
# Out:
# Tamaño de Características: (723, 1)
# Tamaño de Variable Objetivo: (723,)

# %%
X.head()
# Out:
#    Daily Max 8-hour CO Concentration
# 0                                0.2
# 1                                0.7
# 2                                1.3
# 3                                1.1
# 4                                1.4

# %%
y.head()
# Out:
# 0     2
# 1     8
# 2    15
# 3    13
# 4    16
# Name: Daily AQI Value, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
print("Tamaño del conjunto de características del entrenamiento:",X_train.shape)
print("Tamaño del conjunto de características de prueba:",X_test.shape)
print("Tamaño de la variable objetivo del entrenamiento:",y_train.shape)
print("Tamaño de la variable objetivo de prueba:",y_test.shape)
# Out:
# Tamaño del conjunto de características del entrenamiento: (506, 1)
# Tamaño del conjunto de características de prueba: (217, 1)
# Tamaño de la variable objetivo del entrenamiento: (506,)
# Tamaño de la variable objetivo de prueba: (217,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
lm = LinearRegression() # Creando un objeto de Regresión Lineal 'lm'

# %%
lm.fit(X_train,y_train) # Ajuste el modelo lineal en el objeto 'lm' en sí, es decir, no es necesario establecer esto en otra variable
# Out:
# LinearRegression()

# %%
print("El término de intersección del modelo lineal:", lm.intercept_)
# Out:
# El término de intersección del modelo lineal: -0.15040625369526683

# %%
print("Los coeficientes del modelo lineal:", lm.coef_)
# Out:
# Los coeficientes del modelo lineal: [11.54885843]

# %%
#idict = {'Coefficients':lm.intercept_}
#idf = pd.DataFrame(data=idict,index=['Intercept'])
cdf = pd.DataFrame(data=lm.coef_, index=X_train.columns, columns=["Coefficients"])
#cdf=pd.concat([idf,cdf], axis=0)
cdf
# Out:
#                                    Coefficients
# Daily Max 8-hour CO Concentration     11.548858

# %%
n=X_train.shape[0]
k=X_train.shape[1]
dfN = n-k
train_pred=lm.predict(X_train)
train_error = np.square(train_pred - y_train)
sum_error=np.sum(train_error)
se=[0]
for i in range(k):
    r = (sum_error/dfN)
    r = r/np.sum(np.square(X_train[list(X_train.columns)[i]]-X_train[list(X_train.columns)[i]].mean()))
    se[i]=np.sqrt(r)
cdf['Standard Error']=se
cdf['t-statistic']=cdf['Coefficients']/cdf['Standard Error']
cdf
# Out:
#                                    Coefficients  Standard Error  t-statistic
# Daily Max 8-hour CO Concentration     11.548858        0.025586   451.381795

# %%
print("Por lo tanto, las características organizadas en orden de importancia para predecir el precio de la vivienda\n",'-'*90,sep='')
l=list(cdf.sort_values('t-statistic',ascending=False).index)
print(' > \n'.join(l))
# Out:
# Por lo tanto, las características organizadas en orden de importancia para predecir el precio de la vivienda
# ------------------------------------------------------------------------------------------
# Daily Max 8-hour CO Concentration

# %%
l=list(cdf.index)
from matplotlib import gridspec
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(2,3)
#f, ax = plt.subplots(nrows=1,ncols=len(l), sharey=True)
ax = plt.subplot(gs[0])
ax.scatter(df[l[0]],df['Daily AQI Value'])
ax.set_title(l[0]+" vs. Daily AQI Value", fontdict={'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Daily Max 8-hour CO Concentration vs. Daily AQI Value')

# %%
print("Valor del R cuadrado de este ajuste:",round(metrics.r2_score(y_train,train_pred),3))
# Out:
# Valor del R cuadrado de este ajuste: 0.998
